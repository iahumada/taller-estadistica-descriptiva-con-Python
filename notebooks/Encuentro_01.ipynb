# %% [markdown]
# <a href="https://colab.research.google.com/github/iahumada/taller-estadistica-descriptiva-con-Python/blob/main/notebooks/Encuentro_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
print("Entorno OK")
# Out:
# Entorno OK

# %% [markdown]
#  <img src="https://www.eco.unc.edu.ar/files/comunicacion/imagen-institucional/fce-unc1.jpg" align= 'center'/>

# %% [markdown]
# # Denominación: “Análisis descriptivo de datos con Python” 2025
# Tipo de propuesta: Seminario-Taller
# Orientación: Métodos cuantitativos
#
# ## Programa: contenidos por Unidad
#
# **Contenidos Encuentro N°1. Introducción a Python. Cargar datos**
# * Presentación del curso, objetivos y trabajo integrador.
# * Introducción a Python: entorno de trabajo (Google Colab).
# * Manejo básico de librerías.
# * Importación de bases de datos en distintos formatos (CSV, Excel).
# * Exploración inicial: dimensiones de la base, tipos de variables, primeras observaciones.

# %% [markdown]
# ## 📌 Celda guía: cómo abrir el archivo de datos
# Ejemplo de carga de la hoja con datos desde `base.xlsx`.
# Recuerden subir el archivo a Colab (menú *Archivos* → *Subir*).

# %%
import pandas as pd

# Cargar hoja con datos
df = pd.read_excel('Base.xlsx', sheet_name=0)
df.head()

# # Cargar hoja con diccionario de variables
diccionario = pd.read_excel('Base.xlsx', sheet_name=1)
diccionario.head()
# Out:
#      Variable                                        Descripción    Valor1  \
# 0  Id_cliente                                  indicador cliente  Femenino
# 1      genero                                 Género del cliente        Si
# 2       Socio  Indica si el cliente posee categoría comercial...        Si
# 3   Empleados  Indica si el cliente tiene empleados a cargo (...       NaN
# 4       Meses  N° meses que el cliente ha permanecido en la e...        Si
#
#       Valor2 Valor3 Valor3.1
# 0  Masculino    NaN      NaN
# 1         No    NaN      NaN
# 2         No    NaN      NaN
# 3        NaN    NaN      NaN
# 4         No    NaN      NaN

# %%
diccionario
# Out:
#         Variable                                        Descripción  \
# 0     Id_cliente                                  indicador cliente
# 1         genero                                 Género del cliente
# 2          Socio  Indica si el cliente posee categoría comercial...
# 3      Empleados  Indica si el cliente tiene empleados a cargo (...
# 4          Meses  N° meses que el cliente ha permanecido en la e...
# 5       Servicio       Si el cliente tiene servicio telefónico o no
# 6         Lineas             Si el cliente tiene varias líneas o no
# 7       Internet                        Tiene servicios de Internet
# 8      Seguridad  Tiene servicios de seguridad (alarma, monitore...
# 9       Contrato            Plazo del contrato que tiene el cliente
# 10       Factura                   Importe total cargado al cliente
# 11          Pago                         Método de pago del cliente
# 12  Impormensual           Importe cobrado al cliente mensualmente.
# ...

# %% [markdown]
# ## 📌 Celda guía: cómo guardar el archivo trabajado
# Ejemplo para exportar resultados en CSV o Excel. Se recomienda guardar muestras y resultados intermedios.

# %%
#Guardar el archivo original en tu Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv("/content/drive/MyDrive/06_Diplo_Cs_DATOS_FCE/M1.U2.Diplo_FCE/df.csv") #acá debe indicar el path (directorio) dentro del Drive

# %% [markdown]
# Ejemplo de como generar una muestra y luego guardar el archivo en Drive

# %%
# Guardar una muestra en CSV
muestra_simple = df.sample(n=20, random_state=42)
muestra_simple.to_csv('muestra_simple.csv', index=False)

# Guardar resultados en Excel with several sheets
with pd.ExcelWriter('resultados_tp1.xlsx') as writer:
    muestra_simple.to_excel(writer, sheet_name='MuestraSimple', index=False)
    # otros DataFrames pueden guardarse en más hojas
# Out:
#   File "/tmp/ipython-input-3219074099.py", line 2
#     muestra_simple = df.sample(n=20, random_state=42
#                               ^
# SyntaxError: '(' was never closed
